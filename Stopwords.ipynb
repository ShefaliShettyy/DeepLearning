# %% [markdown]
# <a href="https://colab.research.google.com/github/ShefaliShettyy/DeepLearning/blob/main/Stopwords.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

# %%
from spacy.lang.en.stop_words import STOP_WORDS

# %%
STOP_WORDS
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
# ...

# %%
nlp = spacy.load('en_core_web_sm')

doc = nlp("We just opened our wings, the flying part is comming soon")
for token in doc:
  if token.is_stop:
    print(token)
# Out:
# We
# just
# our
# the
# part
# is

# %%
def preprocess(text):
  doc = nlp(text)

  no_stop_words = []
  for token in doc:
    if not token.is_stop and  not token.is_punct:
      no_stop_words.append(token.text)
  return no_stop_words

# %%
preprocess('We just opened our wings, the flying part is comming soon')
# Out:
# ['opened', 'wings', 'flying', 'comming', 'soon']

# %%
#how to apply on dataframe
# df['content_new'] = df['contents'].apply(preprocess) #remove stop words
